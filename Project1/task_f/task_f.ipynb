# %%
from pylab import *

# %%
# %matplotlib inline

# %%
rcParams['font.size'] = 14

# %%
ts = ["{:g}".format(0.05*i) for i in range(101)]

temps = zeros(len(ts))
D = zeros(len(ts))
dt = 0.0025

# %%
for i, ti in enumerate(ts):
    _, TEMP = loadtxt("msd_bath_t{}.txt".format(ti)).T
    r_msd = loadtxt("msd_bath_{}.txt".format(ti))[-1, 1]
    temps[i] = TEMP[-1]
    D[i] = r_msd / (6.0 * len(TEMP) * dt)
    
sort_idx = argsort(temps)

# %%
figure(figsize=(10, 5))
#ylim(0, 0.03)
#xlim(0, 1.)
plot(temps[sort_idx], D[sort_idx])
title("D(t_end) rho=0.8 with bath")
xlabel("Temperature")
ylabel("D")
show()

# %%
for i, ti in enumerate(ts):
    _, TEMP = loadtxt("msd_t{}.txt".format(ti)).T
    r_msd = loadtxt("msd_{}.txt".format(ti))[-1, 1]
    temps[i] = TEMP[-1]
    D[i] = r_msd / (6.0 * len(TEMP) * dt)
    
sort_idx = argsort(temps)

# %%
figure(figsize=(10, 5))
#ylim(0, 0.03)
xlim(1.0, max(temps))
plot(temps[sort_idx], D[sort_idx])
title("D(t_end) rho=0.8 without bath")
xlabel("Temperature [LJ]")
ylabel("D(T)")
show()
